# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Kinase_final_data.csv')
df
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL3648023  CCCCc1ccc(Nc2nnc3cc(-c4cc(OC)cc(OC)c4)cc(C)c3n...
# 1           CHEMBL154969  CONC(=O)CCc1c(SSc2[nH]c3ccccc3c2CCC(=O)NOC)[nH...
# 2           CHEMBL507058              COc1cc(O)c2c(c1)-c1cc(O)c(O)cc1COC2=O
# 3          CHEMBL3401367        COc1cccc(-c2nc3c(O)nc(NC(C)=O)nc3[nH]2)c1OC
# 4          CHEMBL3681299  Cc1nc2cc(-n3ncc(C(=O)c4cc5cc(C(C)(C)C)ccc5[nH]...
# ...                  ...                                                ...
# 21436      CHEMBL3360610  C#Cc1cccc(Nc2ncnc3cc(OCCCCCCn4ccnc4[N+](=O)[O-...
# 21437      CHEMBL1269735                          OCCNc1ncnc2sc3c(c12)CCCC3
# 21438      CHEMBL1276317        O=C1Nc2ccccc2/C1=C1/Nc2ccccc2/C1=N\OCC(O)CO
# 21439       CHEMBL604483  COc1cc2c(Oc3ccc(-c4nc5ccccc5s4)cc3F)ncnc2cc1OC...
# 21440        CHEMBL25425     COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCCC1CCN(C)CC1
#
#        standard_value         class       MW     LogP  NumHDonors  \
# 0           100000.00      inactive  428.536  6.10362           1
# 1             2900.00  intermediate  498.630  4.66900           4
# 2               10.00        active  288.255  2.14940           3
# 3             9130.00  intermediate  329.316  1.70110           3
# 4              150.00        active  412.497  4.64902           3
# ...               ...           ...      ...      ...         ...
# 21436            0.57        active  486.532  5.10740           1
# 21437        20000.00      inactive  249.339  1.97430           2
# 21438          430.00        active  351.362  1.54940           4
# 21439         6100.00  intermediate  559.667  5.86280           0
# 21440          300.00        active  444.938  5.28520           1
#
#        NumHAcceptors     pIC50
# 0                  6  4.000000
# 1                  6  5.537602
# 2                  6  8.000000
# 3                  7  5.039529
# 4                  5  6.823909
# ...              ...       ...
# 21436              9  9.244125
# 21437              5  4.698970
# 21438              6  6.366532
# 21439              9  5.214670
# 21440              6  6.522879
#
# [21441 rows x 9 columns]

# %%
df.dtypes
# Out:
# molecule_chembl_id     object
# canonical_smiles       object
# standard_value        float64
# class                  object
# MW                    float64
# LogP                  float64
# NumHDonors              int64
# NumHAcceptors           int64
# pIC50                 float64
# dtype: object

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# molecule_chembl_id    0.0
# canonical_smiles      0.0
# standard_value        0.0
# class                 0.0
# MW                    0.0
# LogP                  0.0
# NumHDonors            0.0
# NumHAcceptors         0.0
# pIC50                 0.0
# dtype: float64

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
x=df.drop(['molecule_chembl_id','canonical_smiles','pIC50'],axis=1)
y=df['pIC50']

# %%
x
# Out:
#        standard_value         class       MW     LogP  NumHDonors  \
# 0           100000.00      inactive  428.536  6.10362           1
# 1             2900.00  intermediate  498.630  4.66900           4
# 2               10.00        active  288.255  2.14940           3
# 3             9130.00  intermediate  329.316  1.70110           3
# 4              150.00        active  412.497  4.64902           3
# ...               ...           ...      ...      ...         ...
# 21436            0.57        active  486.532  5.10740           1
# 21437        20000.00      inactive  249.339  1.97430           2
# 21438          430.00        active  351.362  1.54940           4
# 21439         6100.00  intermediate  559.667  5.86280           0
# 21440          300.00        active  444.938  5.28520           1
#
#        NumHAcceptors
# 0                  6
# 1                  6
# 2                  6
# 3                  7
# 4                  5
# ...              ...
# 21436              9
# 21437              5
# 21438              6
# 21439              9
# 21440              6
#
# [21441 rows x 6 columns]

# %%
y
# Out:
# 0        4.000000
# 1        5.537602
# 2        8.000000
# 3        5.039529
# 4        6.823909
#            ...
# 21436    9.244125
# 21437    4.698970
# 21438    6.366532
# 21439    5.214670
# 21440    6.522879
# Name: pIC50, Length: 21441, dtype: float64

# %%
df_num=df.select_dtypes(['float64','int64'])

# %%
df_num
# Out:
#        standard_value       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0           100000.00  428.536  6.10362           1              6  4.000000
# 1             2900.00  498.630  4.66900           4              6  5.537602
# 2               10.00  288.255  2.14940           3              6  8.000000
# 3             9130.00  329.316  1.70110           3              7  5.039529
# 4              150.00  412.497  4.64902           3              5  6.823909
# ...               ...      ...      ...         ...            ...       ...
# 21436            0.57  486.532  5.10740           1              9  9.244125
# 21437        20000.00  249.339  1.97430           2              5  4.698970
# 21438          430.00  351.362  1.54940           4              6  6.366532
# 21439         6100.00  559.667  5.86280           0              9  5.214670
# 21440          300.00  444.938  5.28520           1              6  6.522879
#
# [21441 rows x 6 columns]

# %%
df_obj=df.select_dtypes(object)

# %%
df_obj
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL3648023  CCCCc1ccc(Nc2nnc3cc(-c4cc(OC)cc(OC)c4)cc(C)c3n...
# 1           CHEMBL154969  CONC(=O)CCc1c(SSc2[nH]c3ccccc3c2CCC(=O)NOC)[nH...
# 2           CHEMBL507058              COc1cc(O)c2c(c1)-c1cc(O)c(O)cc1COC2=O
# 3          CHEMBL3401367        COc1cccc(-c2nc3c(O)nc(NC(C)=O)nc3[nH]2)c1OC
# 4          CHEMBL3681299  Cc1nc2cc(-n3ncc(C(=O)c4cc5cc(C(C)(C)C)ccc5[nH]...
# ...                  ...                                                ...
# 21436      CHEMBL3360610  C#Cc1cccc(Nc2ncnc3cc(OCCCCCCn4ccnc4[N+](=O)[O-...
# 21437      CHEMBL1269735                          OCCNc1ncnc2sc3c(c12)CCCC3
# 21438      CHEMBL1276317        O=C1Nc2ccccc2/C1=C1/Nc2ccccc2/C1=N\OCC(O)CO
# 21439       CHEMBL604483  COc1cc2c(Oc3ccc(-c4nc5ccccc5s4)cc3F)ncnc2cc1OC...
# 21440        CHEMBL25425     COc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCCC1CCN(C)CC1
#
#               class
# 0          inactive
# 1      intermediate
# 2            active
# 3      intermediate
# 4            active
# ...             ...
# 21436        active
# 21437      inactive
# 21438        active
# 21439  intermediate
# 21440        active
#
# [21441 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df_obj.columns
for i in df_obj:
    df_obj[i]=le.fit_transform(df_obj[i])

# %%
df_obj
# Out:
#        molecule_chembl_id  canonical_smiles  class
# 0                    7076              3626      1
# 1                    1581              7104      2
# 2                   15364              8120      0
# 3                    6355             10966      2
# 4                    7626             13531      0
# ...                   ...               ...    ...
# 21436                6275               240      0
# 21437                1098             17289      1
# 21438                1147             16994      0
# 21439               17073              9401      2
# 21440                4765              9269      0
#
# [21441 rows x 3 columns]

# %%
df_sum=pd.concat([df_obj,df_num],axis=1)

# %%
df_sum
# Out:
#        molecule_chembl_id  canonical_smiles  class  standard_value       MW  \
# 0                    7076              3626      1       100000.00  428.536
# 1                    1581              7104      2         2900.00  498.630
# 2                   15364              8120      0           10.00  288.255
# 3                    6355             10966      2         9130.00  329.316
# 4                    7626             13531      0          150.00  412.497
# ...                   ...               ...    ...             ...      ...
# 21436                6275               240      0            0.57  486.532
# 21437                1098             17289      1        20000.00  249.339
# 21438                1147             16994      0          430.00  351.362
# 21439               17073              9401      2         6100.00  559.667
# 21440                4765              9269      0          300.00  444.938
#
#           LogP  NumHDonors  NumHAcceptors     pIC50
# 0      6.10362           1              6  4.000000
# 1      4.66900           4              6  5.537602
# 2      2.14940           3              6  8.000000
# 3      1.70110           3              7  5.039529
# 4      4.64902           3              5  6.823909
# ...        ...         ...            ...       ...
# 21436  5.10740           1              9  9.244125
# 21437  1.97430           2              5  4.698970
# 21438  1.54940           4              6  6.366532
# 21439  5.86280           0              9  5.214670
# 21440  5.28520           1              6  6.522879
#
# [21441 rows x 9 columns]

# %%
x=df_sum.drop(['molecule_chembl_id','canonical_smiles','pIC50'],axis=1)
y=df_sum['pIC50']

# %%
x
# Out:
#        class  standard_value       MW     LogP  NumHDonors  NumHAcceptors
# 0          1       100000.00  428.536  6.10362           1              6
# 1          2         2900.00  498.630  4.66900           4              6
# 2          0           10.00  288.255  2.14940           3              6
# 3          2         9130.00  329.316  1.70110           3              7
# 4          0          150.00  412.497  4.64902           3              5
# ...      ...             ...      ...      ...         ...            ...
# 21436      0            0.57  486.532  5.10740           1              9
# 21437      1        20000.00  249.339  1.97430           2              5
# 21438      0          430.00  351.362  1.54940           4              6
# 21439      2         6100.00  559.667  5.86280           0              9
# 21440      0          300.00  444.938  5.28520           1              6
#
# [21441 rows x 6 columns]

# %%
y
# Out:
# 0        4.000000
# 1        5.537602
# 2        8.000000
# 3        5.039529
# 4        6.823909
#            ...
# 21436    9.244125
# 21437    4.698970
# 21438    6.366532
# 21439    5.214670
# 21440    6.522879
# Name: pIC50, Length: 21441, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_train
# Out:
#        class  standard_value       MW    LogP  NumHDonors  NumHAcceptors
# 13279      0           850.0  618.828  7.9466           4              4
# 4517       0           100.0  459.550  5.0717           4              6
# 10064      0            46.0  378.501  4.3252           1              5
# 11364      0            50.0  511.779  4.6464           1              7
# 1740       1         10000.0  361.779  4.3097           1              3
# ...      ...             ...      ...     ...         ...            ...
# 10955      2          1230.0  126.111  0.8034           3              3
# 17289      0           350.0  320.179  3.4895           1              4
# 5192       1         16000.0  567.601  3.5069           5              7
# 12172      0          1000.0  518.610  3.6560           2              7
# 235        0           100.0  716.793  7.0420           2             10
#
# [15008 rows x 6 columns]

# %%
y_test
# Out:
# 16072    6.699992
# 16737    8.301030
# 13649    8.301030
# 4140     5.721246
# 15345    4.000000
#            ...
# 10772    7.920819
# 14515    4.301030
# 10914    4.327902
# 13982    7.420216
# 12999    7.714443
# Name: pIC50, Length: 6433, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
x_train
# Out:
# array([[-0.7298253 , -0.01014662,  1.29268853,  2.33598748,  1.17819741,
#         -1.13541524],
#        [-0.7298253 , -0.01018994,  0.01806407,  0.48919319,  1.17819741,
#         -0.22633194],
#        [-0.7298253 , -0.01019305, -0.63053171,  0.00965235, -0.68154036,
#         -0.68087359],
#        ...,
#        [ 0.62108961, -0.00927171,  0.88274373, -0.51601177,  1.79811   ,
#          0.22820971],
#        [-0.7298253 , -0.01013796,  0.49069256, -0.42023208, -0.06162777,
#          0.22820971],
#        [-0.7298253 , -0.01018994,  2.07665484,  1.75488549, -0.06162777,
#          1.59183466]])

# %%
x_test
# Out:
# array([[-0.7298253 , -0.01018419, -1.27197324, -1.94570511,  0.55828482,
#         -0.22633194],
#        [-0.7298253 , -0.01019542,  0.08226824,  0.03727493, -0.68154036,
#         -0.22633194],
#        [-0.7298253 , -0.01019542, -1.04820694, -1.44029541,  1.79811   ,
#         -0.22633194],
#        ...,
#        [ 0.62108961, -0.00748145,  0.51466809,  0.91780569,  1.17819741,
#          0.68275136],
#        [-0.7298253 , -0.01019352, -0.26333635,  0.07615211, -0.68154036,
#         -0.22633194],
#        [-0.7298253 , -0.0101946 ,  0.09162318,  1.36386539,  0.55828482,
#         -1.13541524]])

# %%
import tensorflow as tf

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Dense(units=7,activation='relu',input_shape=(x.shape[1],)),
    #output layer
    tf.keras.layers.Dense(units=1,activation='linear')
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 7)                 49
#
#  dense_11 (Dense)            (None, 1)                 8
#
# =================================================================
# Total params: 57 (228.00 Byte)
# Trainable params: 57 (228.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='sgd',loss='mse')

# %%
#create procedure to decide number of iterations or epochs
#first early stopping class
from tensorflow.keras.callbacks import EarlyStopping 
#create a object of early stopping class
cb=EarlyStopping(
    monitor="val_loss",# val loss validation loss means testing error
    min_delta=0.00001,  #delta min learning rate
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None, #nueral network decided automatic
    restore_best_weights=False #default true but false it will assign first weights

)

# %%
trained_model=model.fit(x_train,y_train,epochs=5000,callbacks=cb,validation_data=(x_test,y_test))
# Out:
# Epoch 1/5000
# 469/469 [==============================] - 3s 4ms/step - loss: 1.5658 - val_loss: 0.7716
# Epoch 2/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 2.8434 - val_loss: 0.6330
# Epoch 3/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6321 - val_loss: 0.6122
# Epoch 4/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6268 - val_loss: 0.6116
# Epoch 5/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6263 - val_loss: 0.6153
# Epoch 6/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6243 - val_loss: 0.6176
# Epoch 7/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6227 - val_loss: 0.6027
# Epoch 8/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6215 - val_loss: 0.6149
# Epoch 9/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6206 - val_loss: 0.6096
# Epoch 10/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6177 - val_loss: 0.6009
# Epoch 11/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6189 - val_loss: 0.6050
# Epoch 12/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6182 - val_loss: 0.6090
# Epoch 13/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6173 - val_loss: 0.6371
# Epoch 14/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6175 - val_loss: 0.5970
# Epoch 15/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6149 - val_loss: 0.6045
# Epoch 16/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6157 - val_loss: 0.5993
# Epoch 17/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6158 - val_loss: 0.6083
# Epoch 18/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6141 - val_loss: 0.6018
# Epoch 19/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6144 - val_loss: 0.6044
# Epoch 20/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6139 - val_loss: 0.6016
# Epoch 21/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6136 - val_loss: 0.5950
# Epoch 22/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6141 - val_loss: 0.5970
# Epoch 23/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6130 - val_loss: 0.5967
# Epoch 24/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6127 - val_loss: 0.5945
# Epoch 25/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6128 - val_loss: 0.5933
# Epoch 26/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6129 - val_loss: 0.6021
# Epoch 27/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6120 - val_loss: 0.5956
# Epoch 28/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6128 - val_loss: 0.6046
# Epoch 29/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6113 - val_loss: 0.5971
# Epoch 30/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6127 - val_loss: 0.6054
# Epoch 31/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6128 - val_loss: 0.5937
# Epoch 32/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6106 - val_loss: 0.5931
# Epoch 33/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6128 - val_loss: 0.6039
# Epoch 34/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6101 - val_loss: 0.6006
# Epoch 35/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6107 - val_loss: 0.6016
# Epoch 36/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6120 - val_loss: 0.5945
# Epoch 37/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6102 - val_loss: 0.5938
# Epoch 38/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6102 - val_loss: 0.5928
# Epoch 39/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6100 - val_loss: 0.5972
# Epoch 40/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6114 - val_loss: 0.5932
# Epoch 41/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6103 - val_loss: 0.6003
# Epoch 42/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6104 - val_loss: 0.6067
# Epoch 43/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6106 - val_loss: 0.6046
# Epoch 44/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6097 - val_loss: 0.5913
# Epoch 45/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6087 - val_loss: 0.5984
# Epoch 46/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6091 - val_loss: 0.5971
# Epoch 47/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6094 - val_loss: 0.5942
# Epoch 48/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6096 - val_loss: 0.6033
# Epoch 49/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6074 - val_loss: 0.5949
# Epoch 50/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6089 - val_loss: 0.5953
# Epoch 51/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6086 - val_loss: 0.6084
# Epoch 52/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6094 - val_loss: 0.5881
# Epoch 53/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6080 - val_loss: 0.5954
# Epoch 54/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6077 - val_loss: 0.5905
# Epoch 55/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6067 - val_loss: 0.5893
# Epoch 56/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6078 - val_loss: 0.5964
# Epoch 57/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6080 - val_loss: 0.5863
# Epoch 58/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6066 - val_loss: 0.5978
# Epoch 59/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6071 - val_loss: 0.6051
# Epoch 60/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6080 - val_loss: 0.5869
# Epoch 61/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6065 - val_loss: 0.5871
# Epoch 62/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6079 - val_loss: 0.5981
# Epoch 63/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6074 - val_loss: 0.6074
# Epoch 64/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6066 - val_loss: 0.5933
# Epoch 65/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6059 - val_loss: 0.5899
# Epoch 66/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6055 - val_loss: 0.5997
# Epoch 67/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6064 - val_loss: 0.6004
# Epoch 68/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6067 - val_loss: 0.6027
# Epoch 69/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6055 - val_loss: 0.5869
# Epoch 70/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6073 - val_loss: 0.5913
# Epoch 71/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6063 - val_loss: 0.5924
# Epoch 72/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6056 - val_loss: 0.5886
# Epoch 73/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6057 - val_loss: 0.5874
# Epoch 74/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6062 - val_loss: 0.5902
# Epoch 75/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6052 - val_loss: 0.5865
# Epoch 76/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6058 - val_loss: 0.5858
# Epoch 77/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6060 - val_loss: 0.5864
# Epoch 78/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6061 - val_loss: 0.5942
# Epoch 79/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6064 - val_loss: 0.5947
# Epoch 80/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6060 - val_loss: 0.5989
# Epoch 81/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6059 - val_loss: 0.5894
# Epoch 82/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6051 - val_loss: 0.5867
# Epoch 83/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6043 - val_loss: 0.5892
# Epoch 84/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6050 - val_loss: 0.5850
# Epoch 85/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6049 - val_loss: 0.5882
# Epoch 86/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6043 - val_loss: 0.5878
# Epoch 87/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6041 - val_loss: 0.5943
# Epoch 88/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6045 - val_loss: 0.5994
# Epoch 89/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6056 - val_loss: 0.5927
# Epoch 90/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6047 - val_loss: 0.5931
# Epoch 91/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6044 - val_loss: 0.5935
# Epoch 92/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6062 - val_loss: 0.5856
# Epoch 93/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6046 - val_loss: 0.5997
# Epoch 94/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6041 - val_loss: 0.5894
# Epoch 95/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6041 - val_loss: 0.5918
# Epoch 96/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6041 - val_loss: 0.5901
# Epoch 97/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6037 - val_loss: 0.6001
# Epoch 98/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6032 - val_loss: 0.5940
# Epoch 99/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6036 - val_loss: 0.5879
# Epoch 100/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6050 - val_loss: 0.5951
# Epoch 101/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6049 - val_loss: 0.5846
# Epoch 102/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6047 - val_loss: 0.5850
# Epoch 103/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6036 - val_loss: 0.5915
# Epoch 104/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6044 - val_loss: 0.5896
# Epoch 105/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6035 - val_loss: 0.5916
# Epoch 106/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6026 - val_loss: 0.5829
# Epoch 107/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6039 - val_loss: 0.5924
# Epoch 108/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6023 - val_loss: 0.5908
# Epoch 109/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6026 - val_loss: 0.5963
# Epoch 110/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6039 - val_loss: 0.5913
# Epoch 111/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6020 - val_loss: 0.5946
# Epoch 112/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6043 - val_loss: 0.5896
# Epoch 113/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6025 - val_loss: 0.5856
# Epoch 114/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6039 - val_loss: 0.5906
# Epoch 115/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6027 - val_loss: 0.6016
# Epoch 116/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6036 - val_loss: 0.5941
# Epoch 117/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6032 - val_loss: 0.5835
# Epoch 118/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6039 - val_loss: 0.5860
# Epoch 119/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6031 - val_loss: 0.5907
# Epoch 120/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6023 - val_loss: 0.5947
# Epoch 121/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6036 - val_loss: 0.5856
# Epoch 122/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6022 - val_loss: 0.5939
# Epoch 123/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6023 - val_loss: 0.5863
# Epoch 124/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6029 - val_loss: 0.6065
# Epoch 125/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6014 - val_loss: 0.5830
# Epoch 126/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6017 - val_loss: 0.5819
# Epoch 127/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6033 - val_loss: 0.5881
# Epoch 128/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6022 - val_loss: 0.5859
# Epoch 129/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6031 - val_loss: 0.5858
# Epoch 130/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6023 - val_loss: 0.5909
# Epoch 131/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6042 - val_loss: 0.5837
# Epoch 132/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6010 - val_loss: 0.5831
# Epoch 133/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6016 - val_loss: 0.5881
# Epoch 134/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6029 - val_loss: 0.5876
# Epoch 135/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6031 - val_loss: 0.5844
# Epoch 136/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6026 - val_loss: 0.5949
# Epoch 137/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6024 - val_loss: 0.5873
# Epoch 138/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6020 - val_loss: 0.5922
# Epoch 139/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6032 - val_loss: 0.5831
# Epoch 140/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6024 - val_loss: 0.6021
# Epoch 141/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6019 - val_loss: 0.5979
# Epoch 142/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6020 - val_loss: 0.5883
# Epoch 143/5000
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6029 - val_loss: 0.5934
# Epoch 144/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6016 - val_loss: 0.5823
# Epoch 145/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6023 - val_loss: 0.5835
# Epoch 146/5000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6019 - val_loss: 0.5866
# Epoch 146: early stopping

# %%
#visulaised loss and epoch
plt.plot(trained_model.history['loss'],label='Training loss')
plt.xlabel("No. of Epochs")
plt.ylabel('Mean square error')
plt.legend()
plt.show()

# %%
plt.plot(trained_model.history['loss'],label='Training loss')
plt.plot(trained_model.history['val_loss'],label='Testing loss')
plt.xlabel("No. of Epochs")
plt.ylabel('Mean square error')
plt.legend()
plt.show()

# %%
model.get_weights() # weight #bais 2 layer weight bais
# Out:
# [array([[ 5.39738655e-01, -4.30052221e-01, -9.39615548e-01,
#           3.72895420e-01,  1.00720477e+00,  1.49797022e-01,
#          -1.55051780e+00],
#         [-9.17885125e-01, -1.74779510e+00, -1.37773800e+00,
#          -7.47100934e-02, -2.14258242e+00, -1.19438963e+01,
#          -1.63783574e+00],
#         [ 5.59488952e-01,  9.62470025e-02,  1.98565908e-02,
#           8.51696670e-01,  5.65751731e-01, -5.05795717e-01,
#          -2.17094481e-01],
#         [ 6.59402668e-01, -5.92104830e-02,  1.06924232e-02,
#          -2.93080777e-01,  8.28296542e-02,  5.04334569e-01,
#          -4.82094008e-03],
#         [ 5.20558059e-01,  1.73539340e-01, -1.01027206e-01,
#          -9.87659171e-02,  1.31191120e-01,  3.66461098e-01,
#           5.49533553e-02],
#         [-2.85295308e-01, -1.18327923e-01,  6.24379963e-02,
#          -8.65888596e-02, -1.06698811e-01,  3.71872663e-01,
#           3.58530134e-02]], dtype=float32),
#  array([ 0.89351064, -0.18802471,  1.0002981 ,  0.01909691,  1.4467413 ,
#         -2.3534558 ,  0.9245787 ], dtype=float32),
#  array([[-0.5086669 ],
#         [ 0.5239635 ],
#         [ 1.2243787 ],
#         [-0.70860535],
#         [ 1.5666229 ],
#         [17.65692   ],
#         [ 1.4159095 ]], dtype=float32),
#  array([1.6096094], dtype=float32)]

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# 202/202 [==============================] - 1s 2ms/step
# array([[7.0558844],
#        [7.613393 ],
#        [7.4877844],
#        ...,
#        [4.568926 ],
#        [7.476864 ],
#        [7.2542934]], dtype=float32)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.7517716484981203

# %%
print("training loss",model.evaluate(x_train,y_train))
print("testing loss",model.evaluate(x_test,y_test))
# Out:
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6043
# training loss 0.6043019890785217
# 202/202 [==============================] - 1s 2ms/step - loss: 0.5866
# testing loss 0.5865921378135681

# %%
import pickle

# %%
input_data=(2,2900.00,498.630,4.66900,4,6)

# %%
#changing the input_data to numpy array
input_data_as_numpy_array=np.asarray(input_data)

# %%
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped)
#standardize the input data
std_data=ss.transform(input_data_reshaped)
print(std_data)
# Out:
# [[2.0000e+00 2.9000e+03 4.9863e+02 4.6690e+00 4.0000e+00 6.0000e+00]]
# [[ 1.97200452 -0.01002823  0.33080232  0.23050451  1.17819741 -0.22633194]]

# %%
predict=model.predict(std_data)
print(predict)
# Out:
# 1/1 [==============================] - 0s 131ms/step
# [[5.4892955]]

# %%
filename='trained_model.sav'
pickle.dump(model,open(filename,'wb'))

# %%
#loading the save model
loaded_model=pickle.load(open('trained_model.sav','rb')) #rb read the binary format

# %%
input_data=(2,2900.00,498.630,4.66900,4,6)
input_data_as_numpy_array=np.asarray(input_data,dtype=object)

#reshape the array as we are predicting for one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
#standardize the input data
std_data=ss.transform(input_data_reshaped)
print(std_data)
predict=loaded_model.predict(std_data)
print(predict)
# Out:
# [[ 1.97200452 -0.01002823  0.33080232  0.23050451  1.17819741 -0.22633194]]
# 1/1 [==============================] - 7s 7s/step
# [[5.4892955]]

# %%
loaded_model = pickle.load(open('C:/Users/yash/Documents/Deeplearning/practise/Chemp/trained_model.sav', 'rb'))
input_data=(2,2900.00,498.630,4.66900,4,6)
input_data_as_numpy_array=np.asarray(input_data,dtype=object)

#reshape the array as we are predicting for one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
#standardize the input data
std_data=ss.transform(input_data_reshaped)
print(std_data)
predict=loaded_model.predict(std_data)
print(predict)
# Out:
# [[ 1.97200452 -0.01002823  0.33080232  0.23050451  1.17819741 -0.22633194]]
# 1/1 [==============================] - 8s 8s/step
# [[5.4892955]]

# %%
filename2='standard_scaler.sav'
pickle.dump(ss,open(filename2,'wb'))
